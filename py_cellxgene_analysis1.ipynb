# %% [markdown]
# # Learning about the CZ CELLxGENE Census

# %% [markdown]
# ## Opening the Census

# %%
import cellxgene_census

# %%
census = cellxgene_census.open_soma()
# Out:
# The "stable" release is currently 2023-05-15. Specify 'census_version="2023-05-15"' in future calls to open_soma() to ensure data consistency.

# %% [markdown]
# ## Cell metadata

# %%
keys = list(census["census_data"]["homo_sapiens"].obs.keys())

# %%
keys
# Out:
# ['soma_joinid',
#  'dataset_id',
#  'assay',
#  'assay_ontology_term_id',
#  'cell_type',
#  'cell_type_ontology_term_id',
#  'development_stage',
#  'development_stage_ontology_term_id',
#  'disease',
#  'disease_ontology_term_id',
#  'donor_id',
#  'is_primary_data',
#  'self_reported_ethnicity',
#  'self_reported_ethnicity_ontology_term_id',
#  'sex',
#  'sex_ontology_term_id',
#  'suspension_type',
#  'tissue',
#  'tissue_ontology_term_id',
#  'tissue_general',
#  'tissue_general_ontology_term_id']

# %% [markdown]
# ## Gene metadata

# %%
keys = list(census["census_data"]["homo_sapiens"].ms["RNA"].var.keys())

# %%
keys
# Out:
# ['soma_joinid', 'feature_id', 'feature_name', 'feature_length']

# %%
census_info = census["census_info"]["summary"].read().concat().to_pandas()

# %%
census_info
# Out:
#    soma_joinid                       label       value
# 0            0       census_schema_version       1.0.0
# 1            1           census_build_date  2023-05-15
# 2            2      dataset_schema_version       3.0.0
# 3            3            total_cell_count    57880760
# 4            4           unique_cell_count    36673205
# 5            5  number_donors_homo_sapiens       12493
# 6            6  number_donors_mus_musculus        1362

# %% [markdown]
# ## Census summary content tables

# %% [markdown]
# ### Cell counts by cell metadata

# %%
census_counts = census["census_info"]["summary_cell_counts"].read().concat().to_pandas()

# %%
census_counts
# Out:
#       soma_joinid      organism        category ontology_term_id  \
# 0               0  Homo sapiens             all               na
# 1               1  Homo sapiens           assay      EFO:0008722
# 2               2  Homo sapiens           assay      EFO:0008780
# 3               3  Homo sapiens           assay      EFO:0008913
# 4               4  Homo sapiens           assay      EFO:0008919
# ...           ...           ...             ...              ...
# 1330         1330  Mus musculus  tissue_general   UBERON:0002113
# 1331         1331  Mus musculus  tissue_general   UBERON:0002365
# 1332         1332  Mus musculus  tissue_general   UBERON:0002367
# 1333         1333  Mus musculus  tissue_general   UBERON:0002368
# 1334         1334  Mus musculus  tissue_general   UBERON:0002371
#
#       unique_cell_count  total_cell_count                       label
# 0              33758887          53794728                          na
# 1                264166            279635                    Drop-seq
# 2                 25652             51304                      inDrop
# 3                133511            133511  single-cell RNA sequencing
# 4                 89477            206754                    Seq-Well
# ...                 ...               ...                         ...
# 1330             179684            208324                      kidney
# 1331              15577             31154              exocrine gland
# 1332              37715            130135              prostate gland
# 1333              13322             26644             endocrine gland
# 1334              90225            144962                 bone marrow
#
# [1335 rows x 7 columns]

# %% [markdown]
# ### Example: cell metadata included in the summary counts table

# %%
census_counts[["organism", "category"]].value_counts(sort=False)
# Out:
# organism      category
# Homo sapiens  all                          1
#               assay                       20
#               cell_type                  604
#               disease                     68
#               self_reported_ethnicity     26
#               sex                          3
#               suspension_type              1
#               tissue                     227
#               tissue_general              61
# Mus musculus  all                          1
#               assay                        9
#               cell_type                  226
#               disease                      5
#               self_reported_ethnicity      1
#               sex                          3
#               suspension_type              1
#               tissue                      51
#               tissue_general              27
# dtype: int64

# %% [markdown]
# ### Example: cell counts for each sequencing assay in human data

# %%
census_human_assays = census_counts.query("organism == 'Homo sapiens' & category == 'assay'")

# %%
census_human_assays.sort_values("total_cell_count", ascending=False)
# Out:
#     soma_joinid      organism category ontology_term_id  unique_cell_count  \
# 11           11  Homo sapiens    assay      EFO:0009922           12559550
# 8             8  Homo sapiens    assay      EFO:0009899            7439891
# 15           15  Homo sapiens    assay      EFO:0011025            3904000
# 14           14  Homo sapiens    assay      EFO:0010550            4062980
# 9             9  Homo sapiens    assay      EFO:0009900            2835156
# 17           17  Homo sapiens    assay      EFO:0030003             744798
# 18           18  Homo sapiens    assay      EFO:0030004             644182
# 16           16  Homo sapiens    assay      EFO:0030002             625175
# 1             1  Homo sapiens    assay      EFO:0008722             264166
# 4             4  Homo sapiens    assay      EFO:0008919              89477
# 19           19  Homo sapiens    assay      EFO:0700003             146278
# 5             5  Homo sapiens    assay      EFO:0008931              78750
# 3             3  Homo sapiens    assay      EFO:0008913             133511
# 10           10  Homo sapiens    assay      EFO:0009901              42397
# 13           13  Homo sapiens    assay      EFO:0010183              58981
# 20           20  Homo sapiens    assay      EFO:0700004              96145
# 2             2  Homo sapiens    assay      EFO:0008780              25652
# 7             7  Homo sapiens    assay      EFO:0008995                  0
# 6             6  Homo sapiens    assay      EFO:0008953               4693
# 12           12  Homo sapiens    assay      EFO:0010010               3105
#
#     total_cell_count                                     label
# 11          23296808                                 10x 3' v3
# 8           12412039                                 10x 3' v2
# 15           6292436                                 10x 5' v1
# 14           5064268                               sci-RNA-seq
# 9            3116133                                 10x 5' v2
# 17            811422            10x 3' transcription profiling
# 18            770127            10x 5' transcription profiling
# 16            642559                             microwell-seq
# 1             279635                                  Drop-seq
# 4             206754                                  Seq-Well
# 19            177276  BD Rhapsody Whole Transcriptome Analysis
# 5             161197                                Smart-seq2
# 3             133511                single-cell RNA sequencing
# 10            121394                                 10x 3' v1
# 13            117962          single cell library construction
# 20             96145                 BD Rhapsody Targeted mRNA
# 2              51304                                    inDrop
# 7              29128                            10x technology
# 6               9386                                  STRT-seq
# 12              5244                                  CEL-seq2

# %% [markdown]
# ### Example: number of microglial cells in the Census

# %%
census_counts.query("label == 'microglial cell'")
# Out:
#       soma_joinid      organism   category ontology_term_id  \
# 70             70  Homo sapiens  cell_type       CL:0000129
# 1048         1048  Mus musculus  cell_type       CL:0000129
#
#       unique_cell_count  total_cell_count            label
# 70               264424            363182  microglial cell
# 1048              48998             62617  microglial cell

# %% [markdown]
# ## Understanding Census contents beyond the summary tables

# %% [markdown]
# ### Example: all cell types available in human

# %%
human_cell_types = (
    census["census_data"]["homo_sapiens"].obs.read(column_names=["cell_type", "is_primary_data"]).concat().to_pandas()
)

# %%
human_cell_types
# Out:
#              cell_type  is_primary_data
# 0         myeloid cell             True
# 1         myeloid cell             True
# 2             fat cell             True
# 3         myeloid cell             True
# 4             fat cell             True
# ...                ...              ...
# 53794723      pericyte             True
# 53794724      pericyte             True
# 53794725      pericyte             True
# 53794726      pericyte             True
# 53794727      pericyte             True
#
# [53794728 rows x 2 columns]

# %%
human_cell_types = (
    census["census_data"]["homo_sapiens"]
    .obs.read(column_names=["cell_type"], value_filter="is_primary_data == True")
    .concat()
    .to_pandas()
)

# %%
human_cell_types
# Out:
#              cell_type  is_primary_data
# 0         myeloid cell             True
# 1         myeloid cell             True
# 2             fat cell             True
# 3         myeloid cell             True
# 4             fat cell             True
# ...                ...              ...
# 33758882      pericyte             True
# 33758883      pericyte             True
# 33758884      pericyte             True
# 33758885      pericyte             True
# 33758886      pericyte             True
#
# [33758887 rows x 2 columns]

# %%
human_cell_types = human_cell_types[["cell_type"]]

# %%
human_cell_types
# Out:
#              cell_type
# 0         myeloid cell
# 1         myeloid cell
# 2             fat cell
# 3         myeloid cell
# 4             fat cell
# ...                ...
# 33758882      pericyte
# 33758883      pericyte
# 33758884      pericyte
# 33758885      pericyte
# 33758886      pericyte
#
# [33758887 rows x 1 columns]

# %%
human_cell_types.shape
# Out:
# (33758887, 1)

# %%
human_cell_type_counts = human_cell_types.value_counts()

# %%
human_cell_type_counts
# Out:
# cell_type
# neuron                                             2682728
# glutamatergic neuron                               1539105
# CD4-positive, alpha-beta T cell                    1274999
# CD8-positive, alpha-beta T cell                    1211278
# classical monocyte                                  998008
#                                                     ...
# microfold cell of epithelium of small intestine         19
# mature conventional dendritic cell                      17
# serous cell of epithelium of bronchus                   15
# sperm                                                   11
# type N enteroendocrine cell                             10
# Length: 588, dtype: int64

# %%
human_cell_type_counts.shape
# Out:
# (588,)

# %% [markdown]
# ### Example: cell types available in human liver

# %%
human_liver_cell_types = (
    census["census_data"]["homo_sapiens"]
    .obs.read(column_names=["cell_type"], value_filter="is_primary_data == True and tissue_general == 'liver'")
    .concat()
    .to_pandas()
)

# %%
human_liver_cell_types
# Out:
#                         cell_type  is_primary_data tissue_general
# 0                        monocyte             True          liver
# 1                        monocyte             True          liver
# 2                        monocyte             True          liver
# 3                        monocyte             True          liver
# 4                        monocyte             True          liver
# ...                           ...              ...            ...
# 567322             dendritic cell             True          liver
# 567323             dendritic cell             True          liver
# 567324             dendritic cell             True          liver
# 567325  erythroid progenitor cell             True          liver
# 567326                     B cell             True          liver
#
# [567327 rows x 3 columns]

# %%
human_liver_cell_types["cell_type"].value_counts()
# Out:
# T cell                                  86780
# hepatoblast                             58447
# neoplastic cell                         52431
# erythroblast                            45605
# monocyte                                34585
#                                         ...
# epithelial cell of exocrine pancreas        1
# enteroendocrine cell                        1
# type I pneumocyte                           1
# endocrine cell                              1
# myelocyte                                   1
# Name: cell_type, Length: 127, dtype: int64

# %% [markdown]
# ### Example: diseased T cells in human tissues

# %%
t_cells_list = ["CD8-positive, alpha-beta T cell", "CD4-positive, alpha-beta T cell"]

# %%
t_cells_list
# Out:
# ['CD8-positive, alpha-beta T cell', 'CD4-positive, alpha-beta T cell']

# %%
t_cells_diseased = (
    census["census_data"]["homo_sapiens"]
    .obs.read(
        column_names=["disease", "tissue_general"],
        value_filter=f"is_primary_data == True and cell_type in {t_cells_list} and disease != 'normal'",
    )
    .concat()
    .to_pandas()
)

# %%
t_cells_diseased
# Out:
#                disease tissue_general  is_primary_data  \
# 0        breast cancer         breast             True
# 1        breast cancer         breast             True
# 2        breast cancer         breast             True
# 3        breast cancer         breast             True
# 4        breast cancer         breast             True
# ...                ...            ...              ...
# 1766292       COVID-19          blood             True
# 1766293       COVID-19          blood             True
# 1766294       COVID-19          blood             True
# 1766295       COVID-19          blood             True
# 1766296       COVID-19          blood             True
#
#                                cell_type
# 0        CD4-positive, alpha-beta T cell
# 1        CD4-positive, alpha-beta T cell
# 2        CD4-positive, alpha-beta T cell
# 3        CD4-positive, alpha-beta T cell
# 4        CD4-positive, alpha-beta T cell
# ...                                  ...
# 1766292  CD4-positive, alpha-beta T cell
# 1766293  CD4-positive, alpha-beta T cell
# 1766294  CD4-positive, alpha-beta T cell
# 1766295  CD4-positive, alpha-beta T cell
# 1766296  CD4-positive, alpha-beta T cell
#
# [1766297 rows x 4 columns]

# %%
t_cells_diseased = t_cells_diseased[["disease", "tissue_general"]].value_counts(sort=False)

# %%
t_cells_diseased
# Out:
# disease                                tissue_general
# B-cell non-Hodgkin lymphoma            blood                  62499
# COVID-19                               blood                 834850
#                                        lung                   30578
#                                        nose                      13
#                                        respiratory system         4
#                                        saliva                    41
# Crohn disease                          colon                  17490
#                                        small intestine        52029
# Down syndrome                          bone marrow              181
# breast cancer                          breast                  1850
# chronic obstructive pulmonary disease  lung                    9382
# chronic rhinitis                       nose                     909
# cystic fibrosis                        lung                       7
# follicular lymphoma                    lymph node              1089
# influenza                              blood                   8871
# interstitial lung disease              lung                    1803
# lung adenocarcinoma                    adrenal gland            205
#                                        brain                   3274
#                                        liver                    507
#                                        lung                  215013
#                                        lymph node             24969
#                                        pleural fluid          11558
# lung large cell carcinoma              lung                    5922
# lymphangioleiomyomatosis               lung                     513
# non-small cell lung carcinoma          lung                   36573
# pleomorphic carcinoma                  lung                    1715
# pneumonia                              lung                     856
# pulmonary fibrosis                     lung                    1671
# respiratory system disorder            blood                  34301
# squamous cell lung carcinoma           lung                   52053
#                                        lymph node               100
# systemic lupus erythematosus           blood                 355471
# dtype: int64

# %%
census.close()
del census
